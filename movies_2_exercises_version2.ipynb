# %%
import pandas as pd
import numpy as np

movies_df = pd.read_csv('movies_2.csv') # Gathering data
movies_df.head(10)
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
# 5        6                  Uncle Buck          PG  15000000.0   79258538.0
# 6        7     When Harry Met Sally...           R  16000000.0   92800000.0
# 7        8          Dead Poets Society          PG  16400000.0  235860116.0
# 8        9                  Parenthood       PG-13  20000000.0  126297830.0
# 9       10             Lethal Weapon 2           R  25000000.0  227853986.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# ...

# %%
# movies_df.drop("Summary", axis='columns', inplace=True)
# movies_df

# %%
movies_df.rename(columns={"MovieID": "movie_id", "Title": "title", "MPAA Rating": "mpaa_rating", "Budget": "budget", 
                          "Gross": "gross", "Release Date": "release_date", "Genre": "genre", "Runtime": "runtime", 
                          "Rating": "rating", "Rating Count": "rating_count"}, inplace=True)
movies_df

# Ola's idea: movies.rename(columns=str.lower) and movies.columns.str.replace(" ","_")
# Out:
#      movie_id                                  title mpaa_rating       budget  \
# 0           1                     Look Who's Talking       PG-13    7500000.0
# 1           2                     Driving Miss Daisy          PG    7500000.0
# 2           3                         Turner & Hooch          PG   13000000.0
# 3           4             Born on the Fourth of July           R   14000000.0
# 4           5                        Field of Dreams          PG   15000000.0
# ..        ...                                    ...         ...          ...
# 611       612                            Toy Story 4           G  200000000.0
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613       614                          The Lion King          PG  250000000.0
# 614       615                      Avengers: Endgame       PG-13  356000000.0
# 615         0                                    NaN         NaN          NaN
#
# ...

# %%
movies_df_615 = movies_df.drop(index=615, inplace=True) #Error in execution of code after removal!
movies_df.reset_index(drop=True, inplace=True)
movies_df
# Out:
#      movie_id                                  title mpaa_rating       budget  \
# 0           1                     Look Who's Talking       PG-13    7500000.0
# 1           2                     Driving Miss Daisy          PG    7500000.0
# 2           3                         Turner & Hooch          PG   13000000.0
# 3           4             Born on the Fourth of July           R   14000000.0
# 4           5                        Field of Dreams          PG   15000000.0
# ..        ...                                    ...         ...          ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611       612                            Toy Story 4           G  200000000.0
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613       614                          The Lion King          PG  250000000.0
# 614       615                      Avengers: Endgame       PG-13  356000000.0
#
# ...

# %%
movies_df.fillna({ 'rating': movies_df['rating'].median() }, inplace=True)
movies_df

# Use median to replace NaN when data set is negatively skewed
# Out:
#      movie_id                                  title mpaa_rating       budget  \
# 0           1                     Look Who's Talking       PG-13    7500000.0
# 1           2                     Driving Miss Daisy          PG    7500000.0
# 2           3                         Turner & Hooch          PG   13000000.0
# 3           4             Born on the Fourth of July           R   14000000.0
# 4           5                        Field of Dreams          PG   15000000.0
# ..        ...                                    ...         ...          ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611       612                            Toy Story 4           G  200000000.0
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613       614                          The Lion King          PG  250000000.0
# 614       615                      Avengers: Endgame       PG-13  356000000.0
#
# ...

# %%
movies_df.fillna({ 'rating_count': movies_df['rating_count'].median() }, inplace=True)
movies_df
# Out:
#      movie_id                                  title mpaa_rating       budget  \
# 0           1                     Look Who's Talking       PG-13    7500000.0
# 1           2                     Driving Miss Daisy          PG    7500000.0
# 2           3                         Turner & Hooch          PG   13000000.0
# 3           4             Born on the Fourth of July           R   14000000.0
# 4           5                        Field of Dreams          PG   15000000.0
# ..        ...                                    ...         ...          ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611       612                            Toy Story 4           G  200000000.0
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613       614                          The Lion King          PG  250000000.0
# 614       615                      Avengers: Endgame       PG-13  356000000.0
#
# ...

# %%
movies_df[movies_df["title"] == 'Jurassic Park III']
# Out:
#      movie_id              title mpaa_rating      budget        gross  \
# 98         99  Jurassic Park III       PG-13  93000000.0  368800000.0
# 249       250  Jurassic Park III       PG-13  93000000.0  368780809.0
#
#     release_date      genre  runtime  rating  rating_count  \
# 98    2001-07-16   Thriller     92.0     8.9     1690474.0
# 249   2001-07-18  Adventure     92.0     5.9      280110.0
#
#                                                Summary
# 98    A decidedly odd couple with ulterior motives ...
# 249  A decidedly odd couple with ulterior motives c...

# %%
movies_df.drop(index=615, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 movies_df.drop(index=615, inplace=True)
#
# File c:\Users\MP_Laptop\anaconda3\envs\EDA_Marc\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
movies_df.columns
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      615 non-null    int64
#  1   title         615 non-null    object
#  2   mpaa_rating   615 non-null    object
#  3   budget        615 non-null    float64
#  4   gross         615 non-null    float64
#  5   release_date  615 non-null    object
#  6   genre         615 non-null    object
#  7   runtime       615 non-null    float64
#  8   rating        508 non-null    float64
#  9   rating_count  508 non-null    float64
#  10  Summary       496 non-null    object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 53.0+ KB

# %%
# movies_df = movies_df.astype({'budget': 'int64', 'gross': 'int64'}, copy=False)
# movies_df.astype({'gross': 'int64'}, copy=False)

# movies_df

movies_df["budget"]
movies_df["budget"]= movies_df["budget"].astype("int32")
movies_df["gross"] = movies_df["gross"].astype("int32")


# Change column B and C's values to integers
# df = df.astype({'B': int, 'C': int})
# Exercise failed. Change does not stick

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      615 non-null    int64
#  1   title         615 non-null    object
#  2   mpaa_rating   615 non-null    object
#  3   budget        615 non-null    int32
#  4   gross         615 non-null    int32
#  5   release_date  615 non-null    object
#  6   genre         615 non-null    object
#  7   runtime       615 non-null    float64
#  8   rating        508 non-null    float64
#  9   rating_count  508 non-null    float64
#  10  Summary       496 non-null    object
# dtypes: float64(3), int32(2), int64(1), object(5)
# memory usage: 48.2+ KB

# %%
movies_df['release_date'] = pd.to_datetime(movies_df['release_date'])
# print(movies_df.to_string())
movies_df

# Other example found: Convert the date to datetime64
# df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
# Out:
#      movie_id                                  title mpaa_rating     budget  \
# 0           1                     Look Who's Talking       PG-13    7500000
# 1           2                     Driving Miss Daisy          PG    7500000
# 2           3                         Turner & Hooch          PG   13000000
# 3           4             Born on the Fourth of July           R   14000000
# 4           5                        Field of Dreams          PG   15000000
# ..        ...                                    ...         ...        ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000
# 611       612                            Toy Story 4           G  200000000
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613       614                          The Lion King          PG  250000000
# 614       615                      Avengers: Endgame       PG-13  356000000
#
# ...

# %%
# Any data value that lies more than 1.5 * IQR away from the Q1 and Q3 quartiles is 
# considered an outlier

# Formula for outlier?

# %%
# show the movies with more than 7 in Rating & greater than 50 million Gross

# show results
#movies_df[(movies_df["rating"] > 7) & (movies_df["gross"] > 50000000.0)]

# shape[0] show only the number of rows  shape[1] shows only he number of columns
movies_df[(movies_df["rating"] > 7) & (movies_df["gross"] > 50000000.0)].shape[0]
# Out:
# 224

# %%
# show the movies with more than 7 in Rating & greater than 50 million Gross & with 
# Parental guidance as MPAA Rating

# only "PG" rated movies
# movies_df[(movies_df["rating"] > 7) & (movies_df["gross"] > 50000000.0) & (movies_df["mpaa_rating"] == 'PG')]

# also shows all rates including PG, i.e. PG and PG13
movies_df[(movies_df["rating"] > 7) & (movies_df["gross"] > 50000000) & (movies_df["mpaa_rating"].str.contains("PG"))]
# Out:
#      movie_id                                  title mpaa_rating       budget  \
# 1           2                     Driving Miss Daisy          PG    7500000.0
# 2           3                         Turner & Hooch          PG   13000000.0
# 4           5                        Field of Dreams          PG   15000000.0
# 7           8                     Dead Poets Society          PG   16400000.0
# 11         12  National Lampoon's Christmas Vacation       PG-13   27000000.0
# ..        ...                                    ...         ...          ...
# 505       506                             Big Hero 6          PG  165000000.0
# 506       507                           Interstellar       PG-13  165000000.0
# 507       508    Captain America: The Winter Soldier       PG-13  170000000.0
# 508       509         Dawn of the Planet of the Apes       PG-13  170000000.0
# 509       510                Guardians of the Galaxy       PG-13  170000000.0
#
# ...

# %%
# show the count of Animation movies with more than 7 in Rating (use the shape() method)

movies_df[(movies_df["genre"] == 'Animation') & (movies_df["rating"] > 7)].shape

# answer: 224 rows, 10 columns
# Out:
# (39, 11)

# %%
# show the top 5 movies based on Budget

# movies_df.head(5)
top5budget = movies_df.nlargest(5, 'budget')
print(top5budget)
# Out:
#      movie_id                                        title mpaa_rating  \
# 594       595                       Avengers: Infinity War       PG-13
# 454       455  Pirates of the Caribbean: On Stranger Tides       PG-13
# 614       615                            Avengers: Endgame       PG-13
# 574       575                     Star Wars: The Last Jedi       PG-13
# 375       376     Pirates of the Caribbean: At World's End       PG-13
#
#           budget         gross release_date            genre  runtime  rating  \
# 594  400000000.0  2.048000e+09   2018-04-23           Action    149.0     6.9
# 454  380000000.0  1.045714e+09   2011-05-14           Action    136.0     6.6
# 614  356000000.0  2.796000e+09   2019-04-22           Action    181.0     6.9
# 574  317000000.0  1.333000e+09   2019-12-09  Science Fiction    152.0     6.9
# 375  300000000.0  9.610000e+08   2007-05-19        Adventure    169.0     7.1
#
#      rating_count
# 594      240347.5
# 454      455211.0
# ...

# %%
# show the top 5 Comedy movies by Rating

top5comedies_rating = movies_df[(movies_df["genre"] == 'Comedy')].nlargest(5, 'rating')
print(top5comedies_rating)
# Out:
#      movie_id                 title mpaa_rating       budget        gross  \
# 111       112          Forrest Gump       PG-13   55000000.0  677945399.0
# 185       186       The Truman Show          PG   60000000.0  264118201.0
# 80         81         Groundhog Day          PG   14600000.0   70906973.0
# 254       255        Monsters, Inc.           G  115000000.0  562816256.0
# 40         41  Fried Green Tomatoes       PG-13   11000000.0  119418501.0
#
#     release_date   genre  runtime  rating  rating_count
# 111   1994-07-06  Comedy    142.0     8.8     1657851.0
# 185   1998-06-04  Comedy    103.0     8.1      859224.0
# 80    1993-02-11  Comedy    101.0     8.0      549538.0
# 254   2001-11-01  Comedy     92.0     8.0      758349.0
# 40    1991-12-27  Comedy    130.0     7.7       62493.0

# %%
# top 5 movie names by Rating

# test : movies_df.nlargest(5, 'rating')
movies_df.nlargest(5, 'rating').loc[:,["title", "rating"]]
# Out:
#                                              title  rating
# 393                                The Dark Knight     9.0
# 83                                Schindler's List     8.9
# 98                               Jurassic Park III     8.9
# 99                                    Pulp Fiction     8.9
# 287  The Lord of the Rings: The Return of the King     8.9

# %%
# top 3 high Gross Romance movies released after 1999 (typecast it to datetime)

top3romance_gross = movies_df[(movies_df["genre"] == 'Romance')].nlargest(3, 'gross')
top3romance_gross

top3romance_gross_aft1999 = movies_df[(movies_df["genre"] == 'Romance') & (movies_df["release_date"] > '1999-12-31')].nlargest(3, 'gross')
top3romance_gross_aft1999


# & (movies_df["release_date"] > 1999)
# Out:
#      movie_id                                      title mpaa_rating  \
# 464       465  The Twilight Saga: Breaking Dawn - Part 2       PG-13
# 442       443  The Twilight Saga: Breaking Dawn - Part 1       PG-13
# 401       402                The Twilight Saga: New Moon       PG-13
#
#         budget      gross release_date    genre  runtime  rating  \
# 464  120000000  829000000   2012-11-13  Romance    115.0     5.5
# 442  110000000  712171856   2011-03-15  Romance    117.0     4.9
# 401   50000000  709827462   2009-03-15  Romance    130.0     4.7
#
#      rating_count                                            Summary
# 464      218357.0  After the birth of Renesmee/Nessie, the Cullen...
# 442      211592.0  The Quileutes close in on expecting parents Ed...
# 401      252223.0  Edward leaves Bella after an attack that nearl...

# %%
# how many Genres are present in the dataframe? (use value_counts() method 
# which applies to Series, not Dataframe)

movies_df["genre"].value_counts().iloc[[0,-1]]
# movies_df["genre"].unique().shape[0]
# Out:
# genre
# Action     110
# History      4
# Name: count, dtype: int64

# %%
# top 5 most expensive movies released after 1999 (measured by Budget)

top5budget_aft1999 = movies_df[(movies_df["release_date"] > '1999-12-31')].nlargest(5, 'budget')
top5budget_aft1999
# Out:
#      movie_id                                        title mpaa_rating  \
# 594       595                       Avengers: Infinity War       PG-13
# 454       455  Pirates of the Caribbean: On Stranger Tides       PG-13
# 614       615                            Avengers: Endgame       PG-13
# 574       575                     Star Wars: The Last Jedi       PG-13
# 375       376     Pirates of the Caribbean: At World's End       PG-13
#
#           budget         gross release_date            genre  runtime  rating  \
# 594  400000000.0  2.048000e+09   2018-04-23           Action    149.0     6.9
# 454  380000000.0  1.045714e+09   2011-05-14           Action    136.0     6.6
# 614  356000000.0  2.796000e+09   2019-04-22           Action    181.0     6.9
# 574  317000000.0  1.333000e+09   2019-12-09  Science Fiction    152.0     6.9
# 375  300000000.0  9.610000e+08   2007-05-19        Adventure    169.0     7.1
#
#      rating_count
# 594      240347.5
# 454      455211.0
# ...

# %%
# most & least frequent MPAA Rating in the dataset in terms of occurrences

# movies_df['mpaa_rating'].min -> does not bring desired output

movies_df["mpaa_rating"].value_counts().iloc[[0,-1]]
# Out:
# mpaa_rating
# PG-13    285
# G         27
# Name: count, dtype: int64

# %%
# most & least expensive Genre (take an average of all Budget measures grouped by Genre
# - use the groupBy() method)

# DataFrame.groupby(by=None, axis=<no_default>, level=None, as_index=True, sort=True, group_keys=True, observed=<no_default>, dropna=True)
# movies_df['budget'] = movies_df.groupby(level="Genre").mean
# movies_df['average_budget'] = movies_df.groupby(level="genre")['budget'].transform('mean')
# movies_df['average_budget'] = movies_df.groupby("genre")['budget'].mean()
# movies_df['average_budget']

# movies_limited = movies_df.loc[:,["genre", "budget"]].groupby.mean()
# movies_limited.groupby.mean()
movies_df.groupby("genre")['budget'].mean().iloc[[0,-1]]

# Answer: least = Horror, Most = Fantasy
# Out:
# genre
# Action     1.441682e+08
# Western    7.983333e+07
# Name: budget, dtype: float64

# %%
# which Genre is favoured the most? 

# mine: movies_df.groupby("genre")['rating'].mean()

# Julien's code: 

movies_df.groupby("genre")["rating"].mean().sort_values(ascending=False).iloc[[0]]
# Answer: History
# Out:
# genre
# History    7.625
# Name: rating, dtype: float64
